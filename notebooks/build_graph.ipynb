# %% [markdown]
# https://methodmatters.github.io/network-community-detection/

# %%
import pandas as pd
import itertools
import numpy as np

cols = ["id", "parent_id", "title", "cited", "publication_data", "snippet"]
df = pd.read_csv("../flask-backend/data/output4.csv", usecols=cols)
df = df.set_index("id")

# %%
def copy_df(input_df):
    return input_df.copy()

def format_numeric_types(df):
    df.cited = df.cited.fillna(0)
    df = df.astype({"parent_id":"float", "cited":"float"})
    return df
    
def format_str_types(df):
    df.publication_data = df.publication_data.str.replace(u"\xa0", " ").str.replace('\u2026', '') # remove ellipsis and non-breaking space
    df[ ["authors", "journal_date"] ] = df.publication_data.str.split(" - ", n=1, expand=True)
    df = df.drop(columns='publication_data')
    df["title"] = df["title"].str.title()
    df["authors"] = df["authors"].str.title()
    df["authors"] = df["authors"].str.split(", ")
    return df
    
def identify_same_articles_under_different_ids(df):
    df = df.reset_index()
    df["id"] = df.groupby('title')["id"].transform(lambda x: min(x)) # donner le même id pour les articles ayant le même nom
    df = df.set_index("id")
    return df

def add_parents_data(df):
    df["authors_of_parent_article"] = df.parent_id.apply(lambda parent_id: df.loc[parent_id, "authors"] if parent_id != -1 else [])
    df["title_of_parent_article"] = df.parent_id.apply(lambda parent_id: df.loc[parent_id, "title"] if parent_id != -1 else [])
    return df

df = (
      df.pipe(copy_df)
        .pipe(format_str_types)
        .pipe(format_numeric_types)
        .pipe(add_parents_data)
        .pipe(identify_same_articles_under_different_ids)
     )

# %%
df.sample(3)
# Out:
#       parent_id                                              title  cited  \
# id
# 942        69.0  Relationship Between Container Ship Underwater...  194.0
# 575       136.0      How To Set Sound Exposure Criteria For Fishes   19.0
# 1365     1350.0  Automatic Rain And Cicada Chorus Filtering Of ...   16.0
#
#                                                 snippet  \
# id
# 942   Low-frequency ocean ambient noise is dominated...
# 575   Underwater sounds from human sources can have ...
# 1365  Recording and analysing environmental audio re...
#
#                                       authors  \
# id
# 942   [Mf Mckenna, Sm Wiggins, Ja Hildebrand]
# 575        [Ad Hawkins, C Johnson, An Popper]
# 1365          [A Brown, S Garg, J Montgomery]
#
#                                        journal_date  \
# id
# 942           Scientific reports, 2013 - nature.com
# 575   The Journal of the , 2020 - asa.scitation.org
# 1365        Applied Soft Computing, 2019 - Elsevier
#
#         authors_of_parent_article  \
# id
# 942   [Sm Wiggins, Ja Hildebrand]
# 575       [An Popper, Ad Hawkins]
# 1365                  [T Ganchev]
#
#                                 title_of_parent_article
# id
# 942   High-Frequency Acoustic Recording Package (Har...
# 575   An Overview Of Fish Bioacoustics And The Impac...
# 1365  Computational Bioacoustics: Biodiversity Monit...

# %%
def create_nodes_from_influential_authors(df, NUMBER_OF_NODES=100):
    total_num_citation_per_author = (df.loc[:, ["title", "authors", "cited"] ]
                                       .drop_duplicates(subset="title")
                                       .explode("authors")
                                       .groupby("authors")
                                       .sum()
                                       .loc[:, 'cited']
                                       .sort_values(ascending=False)
                                       .iloc[:NUMBER_OF_NODES]
                                    )
    
    titles = (df.reset_index()
              .loc[:, ["title", "authors"]]
              .drop_duplicates(subset="title")
              .explode("authors")
           )
    titles = titles.groupby("authors")["title"].apply('<br>'.join)
    titles = titles[total_num_citation_per_author.index]

    return pd.DataFrame(data = {
            "id": range(NUMBER_OF_NODES),
            "author": total_num_citation_per_author.index,
            "#times_cited": total_num_citation_per_author.values, 
            "titles": titles.values
    })

def get_working_relation_between_authors(df, nodes):
    coauthors = df.authors.apply(lambda team: list(itertools.combinations(team, r=2)))
    mask = coauthors.apply(len) > 0
    coauthors = coauthors[mask]
    coauthors = coauthors.explode()
    coauthorship = coauthors.map(lambda t: tuple(sorted(t)))
    edges = coauthorship.value_counts()
    return pd.DataFrame( data = {
            'author1': edges.index.map(lambda t: t[0]),
            'author2': edges.index.map(lambda t: t[1]),
            'number': edges.values 
    })

def names_to_nodes_ids(coauthors_edges, nodes):
    nodes_ids = coauthors_edges[ ["author1", "author2"] ].applymap(lambda name: nodes[nodes.author==name].id.values[0]).reset_index(drop=True)
    return pd.DataFrame( data = { 
            "id_author1": nodes_ids.author1,
            "id_author2": nodes_ids.author2,
            "number": coauthors_edges["number"].values
    })


def get_citing_relation_between_authors(df):
    edges = df.explode('authors').explode("authors_of_parent_article")[["authors", "authors_of_parent_article"]]
    edges = edges.dropna(axis="index")
    edges = edges.reset_index().groupby(["authors", "authors_of_parent_article"]).count()
    edges = edges.reset_index()
    edges.columns = ["author1", "author2", "number"]
    return edges

def select_subset_edges(edges, subset_authors):
    coauthors_to_keep = edges.query('author1 in @subset_authors and author2 in @subset_authors')
    return coauthors_to_keep


def create_coauthor_edges(df, nodes):
    return (df.pipe(lambda df: df.copy(deep=True))
              .pipe(get_working_relation_between_authors, nodes=nodes)
              .pipe(select_subset_edges, subset_authors=nodes.author.values)
              .pipe(names_to_nodes_ids, nodes=nodes)
   )

def create_citing_edges(df, nodes):
    return (df.pipe(lambda df: df.copy(deep=True))
              .pipe(get_citing_relation_between_authors)
              .pipe(select_subset_edges, subset_authors=nodes.author.values)
              .pipe(names_to_nodes_ids, nodes=nodes)
    )

NUMBER_OF_NODES = 100
nodes = create_nodes_from_influential_authors(df, NUMBER_OF_NODES=100)
coauthors_edges = create_coauthor_edges(df, nodes)
citing_edges = create_citing_edges(df, nodes)

# %%
nodes
# Out:
#     id         author  #times_cited  \
# 0    0    Jw Bradbury        4395.0
# 1    1  Sl Vehrencamp        4395.0
# 2    2  H Slabbekoorn        3107.0
# 3    3  Wj Richardson        3080.0
# 4    4       Ci Malme        2842.0
# ..  ..            ...           ...
# 95  95     Rm Rolland         775.0
# 96  96       F Ladich         745.0
# 97  97     A Frantzis         723.0
# 98  98         B Møhl         720.0
# 99  99       Se Moore         714.0
#
#                                                titles  group
# 0                  Principles Of Animal Communication    3.0
# 1                  Principles Of Animal Communication    3.0
# 2   Population‐Level Consequences Of Seismic Surve...   17.0
# 3   Marine Mammals And Noise<br>Influences Of Man‐...    4.0
# 4                            Marine Mammals And Noise    4.0
# ..                                                ...    ...
# 95  Overcoming The Challenges Of Studying Conserva...    8.0
# 96  Diversity In Fish Auditory Systems: One Of The...   -1.0
# 97  A Review Of The Effects Of Seismic Surveys On ...   -1.0
# 98  Estimating Source Position Accuracy Of A Large...    8.0
# 99  A New Framework For Assessing The Effects Of A...    6.0
#
# [100 rows x 5 columns]

# %%
import json
data = {
    "nodes": json.loads(nodes.to_json(orient = "records")),
    "coauthors_edges": json.loads(coauthors_edges.to_json(orient = "records")),
    "citing_edges": json.loads(citing_edges.to_json(orient = "records"))
}

data
# Out:
# {'nodes': [{'id': 0,
#    'author': 'Jw Bradbury',
#    '#times_cited': 4395.0,
#    'titles': 'Principles Of Animal Communication'},
#   {'id': 1,
#    'author': 'Sl Vehrencamp',
#    '#times_cited': 4395.0,
#    'titles': 'Principles Of Animal Communication'},
#   {'id': 2,
#    'author': 'H Slabbekoorn',
#    '#times_cited': 3107.0,
#    'titles': 'Population‐Level Consequences Of Seismic Surveys On Fishes: An Interdisciplinary Challenge<br>Son Et Lumiere: Sound And Light Effects On Spatial Distribution And Swimming Behavior In Captive Zebrafish<br>Birdsong And Anthropogenic Noise: Implications And Applications For Conservation<br>Cities Change The Songs Of Birds<br>Acoustic Communication In Noise<br>A Noisy Spring: The Impact Of Globally Rising Underwater Sound Levels On Fish'},
#   {'id': 3,
#    'author': 'Wj Richardson',
#    '#times_cited': 3080.0,
#    'titles': 'Marine Mammals And Noise<br>Influences Of Man‐Made Noise And Other Human Actions On Cetacean Behaviour'},
#   {'id': 4,
#    'author': 'Ci Malme',
#    '#times_cited': 2842.0,
#    'titles': 'Marine Mammals And Noise'},
#   {'id': 5,
#    'author': 'Dh Thomson',
#    '#times_cited': 2842.0,
#    'titles': 'Marine Mammals And Noise'},
#   {'id': 6,
#    'author': 'Cr Greene Jr',
#    '#times_cited': 2842.0,
#    'titles': 'Marine Mammals And Noise'},
#   {'id': 7,
#    'author': 'An Popper',
#    '#times_cited': 2792.0,
#    'titles': "Bat Bioacoustics<br>An Overview Of Fish Bioacoustics And The Impacts Of Anthropogenic Sounds On Fishes<br>Fish Bioacoustics<br>Some Lessons From The Effects Of Highway Noise On Birds<br>A Sound Approach To Assessing The Impact Of Underwater Noise On Marine Fishes And Invertebrates<br>Central And Peripheral Mechanisms Of Teleost Sound Production<br>The Effects Of Anthropogenic Sources Of Sound On Fishes<br>Rethinking Sound Detection By Fishes<br>Application Of Sound And Other Stimuli To Control Fish Behavior<br>Sound Exposure Guidelines<br>Examining The Hearing Abilities Of Fishes<br>Taking The Animals' Perspective Regarding Anthropogenic Underwater Sound<br>How To Set Sound Exposure Criteria For Fishes<br>Fish Hearing And How It Is Best Determined<br>Effects Of Exposure To Seismic Airgun Use On Hearing Of Three Fish Species<br>The Effects Of Human‐Generated Sound On Fish<br>The Effects Of High-Intensity, Low-Frequency Active Sonar On Rainbow Trout"},
#   {'id': 8,
#    'author': 'Cw Clark',
#    '#times_cited': 2560.0,
#    'titles': 'Mobysound: A Reference Archive For Studying Automatic Recognition Of Marine Mammal Sounds<br>…\xa04: Dcl System Using Deep Learning Approaches For Land-Based Or Ship-Based Real-Time Recognition And Localization Of Marine Mammals-Distributed Processing And Big\xa0…<br>Dcl System Using Deep Learning Approaches For Land-Based Or Ship-Based Real Time Recognition And Localization Of Marine Mammals<br>Dcl System Research Using Advanced Approaches For Land-Based Or Ship-Based Real-Time Recognition And Localization Of Marine Mammals<br>A New Context‐Based Approach To Assess Marine Mammal Behavioral Responses To Anthropogenic Sounds<br>…\xa0Research Using Advanced Approaches For Land-Based Or Ship-Based Real-Time Recognition And Localization Of Marine Mammals-Hpc System Implementation<br>Communicating Amidst The Noise: Modeling The Aggregate Influence Of Ambient And Vessel Noise On Baleen Whale Communication Space In A National Marine\xa0…<br>Management And Research Applications Of Real-Time And Archival Passive Acoustic Sensors Over Varying Temporal And Spatial Scales<br>Comparative Analysis Of Localization Algorithms With Application To Passive Acoustic Monitoring<br>Quantifying Loss Of Acoustic Communication Space For Right Whales In And Around A Us National Marine Sanctuary<br>Minke Whale Acoustic Behavior And Multi-Year Seasonal And Diel Vocalization Patterns In Massachusetts Bay, Usa<br>Seasonal Migrations Of North Atlantic Minke Whales: Novel Insights From Large-Scale Passive Acoustic Monitoring Networks<br>Communication And Acoustic Behavior Of Dolphins And Whales<br>Acoustic Masking In Marine Ecosystems: Intuitions, Analysis, And Implication<br>Exposure To Seismic Survey Alters Blue Whale Acoustic Communication<br>Acoustic Quality Of Critical Habitats For Three Threatened Whale Populations'},
#   {'id': 9,
#    'author': 'Pl Tyack',
#    '#times_cited': 2395.0,
#    'titles': 'Implications For Marine Mammals Of Large-Scale Changes In The Marine Acoustic Environment<br>A Digital Acoustic Recording Tag For Measuring The Response Of Wild Marine Mammals To Sound<br>Three-Dimensional Beam Pattern Of Regular Sperm Whale Clicks Confirms Bent-Horn Hypothesis<br>Acoustic Communication Under The Sea<br>Controlled Sonar Exposure Experiments On Cetaceans In Norwegian Waters: Overview Of The 3S-Project<br>Communication And Acoustic Behavior Of Dolphins And Whales<br>Extreme Diving Of Beaked Whales'},
#   {'id': 10,
#    'author': 'M Johnson',
#    '#times_cited': 2009.0,
#    'titles': 'Studying The Behaviour And Sensory Ecology Of Marine Mammals Using Acoustic Recording Tags: A Review<br>A 2.6‐G Sound And Movement Tag For Studying The Acoustic Scene And Kinematics Of Echolocating Bats<br>Extreme Diving Of Beaked Whales<br>Beaked Whales Echolocate On Prey<br>Individual Right Whales Call Louder In Increased Environmental Noise<br>Ultra-High Foraging Rates Of Harbor Porpoises Make Them Vulnerable To Anthropogenic Disturbance<br>Keeping Momentum With A Mouthful Of Water: Behavior And Kinematics Of Humpback Whale Lunge Feeding<br>High Rates Of Vessel Noise Disrupt Foraging In Wild Harbour Porpoises (Phocoena Phocoena)'},
#   {'id': 11,
#    'author': 'A Mayr',
#    '#times_cited': 1992.0,
#    'titles': 'Self-Normalizing Neural Networks'},
#   {'id': 12,
#    'author': 'G Klambauer',
#    '#times_cited': 1992.0,
#    'titles': 'Self-Normalizing Neural Networks'},
#   {'id': 13,
#    'author': 'T Unterthiner',
#    '#times_cited': 1992.0,
#    'titles': 'Self-Normalizing Neural Networks'},
#   {'id': 14,
#    'author': 'Pt Madsen',
#    '#times_cited': 1967.0,
#    'titles': "Studying The Behaviour And Sensory Ecology Of Marine Mammals Using Acoustic Recording Tags: A Review<br>The Monopulsed Nature Of Sperm Whale Clicks<br>Echolocation Clicks Of Two Free-Ranging, Oceanic Delphinids With Different Food Preferences: False Killer Whales Pseudorca Crassidens And Risso'S Dolphins Grampus\xa0…<br>Recording And Quantification Of Ultrasonic Echolocation Clicks From Free-Ranging Toothed Whales<br>Echolocation Clicks Of Free-Ranging Cuvier'S Beaked Whales (Ziphius Cavirostris)<br>Cetacean Noise Criteria Revisited In The Light Of Proposed Exposure Limits For Harbour Porpoises<br>Beaked Whales Echolocate On Prey<br>Following A Foraging Fish-Finder: Diel Habitat Use Of Blainville'S Beaked Whales Revealed By Echolocation"},
#   {'id': 15,
#    'author': 'Ja Hildebrand',
#    '#times_cited': 1935.0,
#    'titles': 'High-Frequency Acoustic Recording Package (Harp) For Broad-Band, Long-Term Marine Mammal Monitoring<br>Performance Metrics For Marine Mammal Signal Detection And Classification<br>A Robust Model-Based Algorithm For Localizing Marine Mammal Transients<br>Relationship Between Container Ship Underwater Noise Levels And Ship Design, Operational And Oceanographic Conditions<br>Worldwide Decline In Tonal Frequencies Of Blue Whale Songs<br>Anthropogenic And Natural Sources Of Ambient Noise In The Ocean<br>Glider-Based Passive Acoustic Monitoring Techniques In The Southern California Region<br>Seasonality Of Blue And Fin Whale Calls And The Influence Of Sea Ice In The Western Antarctic Peninsula'},
#   {'id': 16,
#    'author': 'Wl Allen',
#    '#times_cited': 1919.0,
#    'titles': 'Assessing The Potential Information Content Of Multicomponent Visual Signals: A Machine Learning Approach<br>Avoiding Attack: The Evolutionary Ecology Of Crypsis, Aposematism, And Mimicry'},
#   {'id': 17,
#    'author': 'Bc Pijanowski',
#    '#times_cited': 1889.0,
#    'titles': 'The Silence Of Biogeography<br>What Is Soundscape Ecology? An Introduction And Overview Of An Emerging New Science<br>Soundscape Ecology: The Science Of Sound In The Landscape<br>A Primer Of Acoustic Analysis For Landscape Ecologists<br>Human And Policy Dimensions Of Soundscape Ecology'},
#   {'id': 18,
#    'author': 'Mp Speed',
#    '#times_cited': 1886.0,
#    'titles': 'Avoiding Attack: The Evolutionary Ecology Of Crypsis, Aposematism, And Mimicry'},
#   {'id': 19,
#    'author': 'Gd Ruxton',
#    '#times_cited': 1886.0,
#    'titles': 'Avoiding Attack: The Evolutionary Ecology Of Crypsis, Aposematism, And Mimicry'},
#   {'id': 20,
#    'author': 'Tn Sherratt',
#    '#times_cited': 1886.0,
#    'titles': 'Avoiding Attack: The Evolutionary Ecology Of Crypsis, Aposematism, And Mimicry'},
#   {'id': 21,
#    'author': 'A Farina',
#    '#times_cited': 1846.0,
#    'titles': 'Soundscape Ecology: Principles, Patterns, Methods And Applications<br>Ecoacoustics: The Ecological Investigation And Interpretation Of Environmental Sound<br>What Is Soundscape Ecology? An Introduction And Overview Of An Emerging New Science<br>Ecoacoustics: A Quantitative Approach To Investigate The Ecological Role Of Environmental Sounds<br>Using Ecoacoustic Methods To Survey The Impacts Of Climate Change On Biodiversity<br>Acoustic Indices For Biodiversity Assessment And Landscape Investigation<br>Perspectives On The Ecological Role Of Geophysical Sounds'},
#   {'id': 22,
#    'author': 'Mp Johnson',
#    '#times_cited': 1780.0,
#    'titles': "A Digital Acoustic Recording Tag For Measuring The Response Of Wild Marine Mammals To Sound<br>Three-Dimensional Beam Pattern Of Regular Sperm Whale Clicks Confirms Bent-Horn Hypothesis<br>Combining Data From A Multisensor Tag And Passive Sonar To Determine The Diving Behavior Of A Sperm Whale (Physeter Macrocephalus)<br>Measuring Acoustic Habitats<br>Echolocation Clicks Of Free-Ranging Cuvier'S Beaked Whales (Ziphius Cavirostris)"},
#   {'id': 23,
#    'author': 'J Simmonds',
#    '#times_cited': 1757.0,
#    'titles': 'Fisheries Acoustics: Theory And Practice'},
#   {'id': 24,
#    'author': 'Dn Maclennan',
#    '#times_cited': 1757.0,
#    'titles': 'Fisheries Acoustics: Theory And Practice'},
#   {'id': 25,
#    'author': 'Jr Barber',
#    '#times_cited': 1638.0,
#    'titles': 'The Costs Of Chronic Noise Exposure For Terrestrial Organisms<br>A Framework For Understanding Noise Impacts On Wildlife: An Urgent Conservation Priority<br>Acoustic Mimicry In A Predator–Prey Interaction<br>Phantom River Noise Alters Orb-Weaving Spider Abundance, Web Size, And Prey Capture'},
#   {'id': 26,
#    'author': 'J Müller',
#    '#times_cited': 1631.0,
#    'titles': 'Geodesy'},
#   {'id': 27, 'author': 'W Torge', '#times_cited': 1631.0, 'titles': 'Geodesy'},
#   {'id': 28,
#    'author': 'Sl Fowler',
#    '#times_cited': 1592.0,
#    'titles': "Extinction Risk And Conservation Of The World'S Sharks And Rays"},
#   {'id': 29,
#    'author': 'Ja Musick',
#    '#times_cited': 1592.0,
#    'titles': "Extinction Risk And Conservation Of The World'S Sharks And Rays"},
#   {'id': 30,
#    'author': 'Rd Cavanagh',
#    '#times_cited': 1592.0,
#    'titles': "Extinction Risk And Conservation Of The World'S Sharks And Rays"},
#   {'id': 31,
#    'author': 'Nk Dulvy',
#    '#times_cited': 1592.0,
#    'titles': "Extinction Risk And Conservation Of The World'S Sharks And Rays"},
#   {'id': 32,
#    'author': 'Sl Dumyahn',
#    '#times_cited': 1583.0,
#    'titles': 'What Is Soundscape Ecology? An Introduction And Overview Of An Emerging New Science<br>Soundscape Ecology: The Science Of Sound In The Landscape'},
#   {'id': 33,
#    'author': 'H Brumm',
#    '#times_cited': 1582.0,
#    'titles': 'Acoustic Communication In Noise<br>The Evolution Of The Lombard Effect: 100 Years Of Psychoacoustic Research<br>Birds And Anthropogenic Noise: Are Urban Songs Adaptive?'},
#   {'id': 34,
#    'author': 'Rh Liu',
#    '#times_cited': 1521.0,
#    'titles': 'Antioxidant Activity Of Fresh Apples'},
#   {'id': 35,
#    'author': 'Mv Eberhardt',
#    '#times_cited': 1521.0,
#    'titles': 'Antioxidant Activity Of Fresh Apples'},
#   {'id': 36,
#    'author': 'Cy Lee',
#    '#times_cited': 1521.0,
#    'titles': 'Antioxidant Activity Of Fresh Apples'},
#   {'id': 37,
#    'author': 'H Whitehead',
#    '#times_cited': 1503.0,
#    'titles': 'Sperm Whales: Social Evolution In The Ocean<br>The Cultural Lives Of Whales And Dolphins<br>Social Organization In Northern Bottlenose Whales, Hyperoodon Ampullatus: Not Driven By Deep-Water Foraging?<br>Movements And Distribution Of Northern Bottlenose Whales, Hyperoodon Ampullatus, On The Scotian Slope And In Adjacent Waters<br>Ecosystem Consideration In Conservation Planning: Energy Demand Of Foraging Bottlenose Whales (Hyperoodon Ampullatus) In A Marine Protected Area<br>Population Size And Residency Patterns Of Northern Bottlenose Whales (Hyperoodon Ampullatus) Using The Gully, Nova Scotia<br>Click Characteristics Of Northern Bottlenose Whales (Hyperoodon Ampullatus)'},
#   {'id': 38,
#    'author': 'M Wahlberg',
#    '#times_cited': 1500.0,
#    'titles': 'Estimating Source Position Accuracy Of A Large-Aperture Hydrophone Array For Bioacoustics<br>The Monopulsed Nature Of Sperm Whale Clicks<br>Echolocation Signals Of Wild Harbour Porpoises, Phocoena Phocoena<br>Male Sperm Whale (Physeter Macrocephalus) Acoustics In A High-Latitude Habitat: Implications For Echolocation And Communication<br>Recording And Quantification Of Ultrasonic Echolocation Clicks From Free-Ranging Toothed Whales<br>Vessel Noise Effects On Delphinid Communication<br>Source Parameters Of Echolocation Clicks From Wild Bottlenose Dolphins (Tursiops Aduncus And Tursiops Truncatus)'},
#   {'id': 39,
#    'author': 'Km Fristrup',
#    '#times_cited': 1486.0,
#    'titles': 'The Costs Of Chronic Noise Exposure For Terrestrial Organisms<br>Measuring Acoustic Habitats<br>Accuracy Of An Acoustic Location System For Monitoring The Position Of Duetting Songbirds In Tropical Forest'},
#   {'id': 40,
#    'author': 'Bl Southall',
#    '#times_cited': 1483.0,
#    'titles': 'A New Framework For Assessing The Effects Of Anthropogenic Sound On Marine Mammals In A Rapidly Changing Arctic<br>A New Context‐Based Approach To Assess Marine Mammal Behavioral Responses To Anthropogenic Sounds<br>An Integrated Underwater Soundscape Analysis In The Bering Strait Region<br>Blue Whales Respond To Simulated Mid-Frequency Military Sonar<br>Acoustic Masking In Marine Ecosystems: Intuitions, Analysis, And Implication'},
#   {'id': 41,
#    'author': 'X Lurton',
#    '#times_cited': 1472.0,
#    'titles': 'An Introduction To Underwater Acoustics: Principles And Applications'},
#   {'id': 42,
#    'author': 'A Zahavi',
#    '#times_cited': 1407.0,
#    'titles': 'The Importance Of Certain Assemblages Of Birds As “Information‐Centres” For Food‐Finding'},
#   {'id': 43,
#    'author': 'P Ward',
#    '#times_cited': 1407.0,
#    'titles': 'The Importance Of Certain Assemblages Of Birds As “Information‐Centres” For Food‐Finding'},
#   {'id': 44,
#    'author': 'Km Bailey',
#    '#times_cited': 1382.0,
#    'titles': 'Predation On Eggs And Larvae Of Marine Fishes And The Recruitment Problem'},
#   {'id': 45,
#    'author': 'Ed Houde',
#    '#times_cited': 1382.0,
#    'titles': 'Predation On Eggs And Larvae Of Marine Fishes And The Recruitment Problem'},
#   {'id': 46,
#    'author': 'Sm Wiggins',
#    '#times_cited': 1362.0,
#    'titles': "High-Frequency Acoustic Recording Package (Harp) For Broad-Band, Long-Term Marine Mammal Monitoring<br>Temporal Separation Of Two Fin Whale Call Types Across The Eastern North Pacific<br>Discriminating Features Of Echolocation Clicks Of Melon-Headed Whales (Peponocephala Electra), Bottlenose Dolphins (Tursiops Truncatus), And Gray'S Spinner\xa0…<br>Underwater Radiated Noise From Modern Commercial Ships<br>Relationship Between Container Ship Underwater Noise Levels And Ship Design, Operational And Oceanographic Conditions<br>Seasonality Of Blue And Fin Whale Calls And The Influence Of Sea Ice In The Western Antarctic Peninsula"},
#   {'id': 47,
#    'author': 'Mc Hastings',
#    '#times_cited': 1276.0,
#    'titles': 'Principles Of Marine Bioacoustics<br>The Effects Of Anthropogenic Sources Of Sound On Fishes<br>The Effects Of Human‐Generated Sound On Fish'},
#   {'id': 48,
#    'author': 'Rr Reeves',
#    '#times_cited': 1261.0,
#    'titles': "A New Framework For Assessing The Effects Of Anthropogenic Sound On Marine Mammals In A Rapidly Changing Arctic<br>Distribution Of Endemic Cetaceans In Relation To Hydrocarbon Development And Commercial Shipping In A Warming Arctic<br>Status Of The World'S Baleen Whales<br>Dolphins, Whales And Porpoises: 2002-2010 Conservation Action Plan For The World'S Cetaceans<br>Ecology, Status And Conservation Of Short‐Beaked Common Dolphins Delphinus Delphis In The Mediterranean Sea"},
#   {'id': 49,
#    'author': 'Wc Leggett',
#    '#times_cited': 1243.0,
#    'titles': 'Recruitment In Marine Fishes: Is It Regulated By Starvation And Predation In The Egg And Larval Stages?<br>An Appraisal Of Condition Measures For Marine Fish Larvae'},
#   {'id': 50,
#    'author': 'Mf Mckenna',
#    '#times_cited': 1231.0,
#    'titles': 'An Integrated Underwater Soundscape Analysis In The Bering Strait Region<br>A Synthesis Of Two Decades Of Research Documenting The Effects Of Noise On Wildlife<br>Advancing The Interpretation Of Shallow Water Marine Soundscapes<br>Underwater Radiated Noise From Modern Commercial Ships<br>Relationship Between Container Ship Underwater Noise Levels And Ship Design, Operational And Oceanographic Conditions'},
#   {'id': 51,
#    'author': 'Lj Villanueva-Rivera',
#    '#times_cited': 1214.0,
#    'titles': 'Soundscape Ecology: The Science Of Sound In The Landscape<br>A Primer Of Acoustic Analysis For Landscape Ecologists'},
#   {'id': 52,
#    'author': 'Sh Gage',
#    '#times_cited': 1214.0,
#    'titles': "The Remote Environmental Assessment Laboratory'S Acoustic Library: An Archive For Studying Soundscape Ecology<br>Connecting Soundscape To Landscape: Which Acoustic Index Best Describes Landscape Configuration?<br>Analysis And Interpretation Of Variability In Soundscapes Along An Urban–Rural Gradient<br>What Is Soundscape Ecology? An Introduction And Overview Of An Emerging New Science"},
#   {'id': 53,
#    'author': 'Na Soto',
#    '#times_cited': 1201.0,
#    'titles': 'Do Marine Mammals Experience Stress Related To Anthropogenic Noise?<br>Anthropogenic Noise As A Stressor In Animals: A Multidisciplinary Perspective<br>Extreme Diving Of Beaked Whales<br>Vessel Noise Effects On Delphinid Communication'},
#   {'id': 54,
#    'author': 'J Fischer',
#    '#times_cited': 1196.0,
#    'titles': 'Habitat Fragmentation And Landscape Change: An Ecological And Conservation Synthesis'},
#   {'id': 55,
#    'author': 'Db Lindenmayer',
#    '#times_cited': 1196.0,
#    'titles': 'Habitat Fragmentation And Landscape Change: An Ecological And Conservation Synthesis'},
#   {'id': 56,
#    'author': 'Gp Asner',
#    '#times_cited': 1176.0,
#    'titles': 'Scaling Up Coral Reef Restoration Using Remote Sensing Technology<br>Multi‐Trophic Invasion Resistance In Hawaii: Bioacoustics, Field Surveys, And Airborne Remote Sensing<br>Carnegie Airborne Observatory-2: Increasing Science Data Dimensionality Via High-Fidelity Multi-Sensor Fusion<br>Applications Of Remote Sensing To Alien Invasive Plant Studies<br>Advances In Animal Ecology From 3D-Lidar Ecosystem Mapping<br>Long-Term Effects Of Fragmentation And Fragment Properties On Bird Species Richness In Hawaiian Forests'},
#   {'id': 57,
#    'author': 'Cd Francis',
#    '#times_cited': 1158.0,
#    'titles': 'Noise Pollution Changes Avian Communities And Species Interactions<br>A Framework For Understanding Noise Impacts On Wildlife: An Urgent Conservation Priority'},
#   {'id': 58,
#    'author': 'Aj Wright',
#    '#times_cited': 1155.0,
#    'titles': 'A Systematic Review On The Behavioural Responses Of Wild Marine Mammals To Noise: The Disparity Between Science And Policy<br>Do Marine Mammals Experience Stress Related To Anthropogenic Noise?<br>Anthropogenic Noise As A Stressor In Animals: A Multidisciplinary Perspective<br>Navy Sonar And Cetaceans: Just How Much Does The Gun Need To Smoke Before We Act?<br>Cetacean Noise Criteria Revisited In The Light Of Proposed Exposure Limits For Harbour Porpoises<br>Size Matters: Management Of Stress Responses And Chronic Stress In Beaked Whales And Other Marine Mammals May Require Larger Exclusion Zones<br>Impacts Of Anthropogenic Noise On Marine Life: Publication Patterns, New Discoveries, And Future Directions In Research And Management'},
#   {'id': 59,
#    'author': 'Wt Ellison',
#    '#times_cited': 1135.0,
#    'titles': 'A New Context‐Based Approach To Assess Marine Mammal Behavioral Responses To Anthropogenic Sounds<br>Application Of The Acoustic Integration Model (Aim) To Predict And Minimize Environmental Impacts<br>Acoustic Masking In Marine Ecosystems: Intuitions, Analysis, And Implication'},
#   {'id': 60,
#    'author': 'Ml Cadenasso',
#    '#times_cited': 1074.0,
#    'titles': 'Urban Ecological Systems: Scientific Foundations And A Decade Of Progress'},
#   {'id': 61,
#    'author': 'Sta Pickett',
#    '#times_cited': 1074.0,
#    'titles': 'Urban Ecological Systems: Scientific Foundations And A Decade Of Progress'},
#   {'id': 62,
#    'author': 'Jm Grove',
#    '#times_cited': 1074.0,
#    'titles': 'Urban Ecological Systems: Scientific Foundations And A Decade Of Progress'},
#   {'id': 63,
#    'author': 'J Cruz',
#    '#times_cited': 1073.0,
#    'titles': 'Ocean Wave Energy: Current Status And Future Prespectives'},
#   {'id': 64,
#    'author': 'Sa Fritz',
#    '#times_cited': 1032.0,
#    'titles': "An Update Of Wallace'S Zoogeographic Regions Of The World"},
#   {'id': 65,
#    'author': 'Bg Holt',
#    '#times_cited': 1032.0,
#    'titles': "An Update Of Wallace'S Zoogeographic Regions Of The World"},
#   {'id': 66,
#    'author': 'Jp Lessard',
#    '#times_cited': 1032.0,
#    'titles': "An Update Of Wallace'S Zoogeographic Regions Of The World"},
#   {'id': 67,
#    'author': 'Mk Borregaard',
#    '#times_cited': 1032.0,
#    'titles': "An Update Of Wallace'S Zoogeographic Regions Of The World"},
#   {'id': 68,
#    'author': 'Ad Hawkins',
#    '#times_cited': 1031.0,
#    'titles': "An Overview Of Fish Bioacoustics And The Impacts Of Anthropogenic Sounds On Fishes<br>A Sound Approach To Assessing The Impact Of Underwater Noise On Marine Fishes And Invertebrates<br>A Field Study Of Hearing In The Cod, Gadus Morhua L.<br>Sound Exposure Guidelines<br>Examining The Hearing Abilities Of Fishes<br>Taking The Animals' Perspective Regarding Anthropogenic Underwater Sound<br>The Importance Of Underwater Sounds To Gadoid Fishes<br>How To Set Sound Exposure Criteria For Fishes<br>Fish Hearing And How It Is Best Determined<br>Acoustic Indices Provide Information On The Status Of Coral Reefs: An Example From Moorea Island In The South Pacific"},
#   {'id': 69,
#    'author': 'Kr Crooks',
#    '#times_cited': 1014.0,
#    'titles': 'The Costs Of Chronic Noise Exposure For Terrestrial Organisms'},
#   {'id': 70,
#    'author': 'N Bouton',
#    '#times_cited': 996.0,
#    'titles': 'Sounds Of Male Lake Victoria Cichlids Vary Within And Between Species And Affect Female Mate Preferences<br>A Noisy Spring: The Impact Of Globally Rising Underwater Sound Levels On Fish'},
#   {'id': 71,
#    'author': 'Jr Geraci',
#    '#times_cited': 959.0,
#    'titles': 'Marine Mammals Ashore: A Field Guide For Strandings'},
#   {'id': 72,
#    'author': 'Vj Lounsbury',
#    '#times_cited': 959.0,
#    'titles': 'Marine Mammals Ashore: A Field Guide For Strandings'},
#   {'id': 73,
#    'author': 'Hw Ducklow',
#    '#times_cited': 937.0,
#    'titles': 'Marine Pelagic Ecosystems: The West Antarctic Peninsula<br>West Antarctic Peninsula: An Ice-Dependent Coastal Marine Ecosystem In Transition'},
#   {'id': 74,
#    'author': 'Dw Johnston',
#    '#times_cited': 936.0,
#    'titles': 'Ecological Niche Modeling Of Sympatric Krill Predators Around Marguerite Bay, Western Antarctic Peninsula<br>Responses Of Cetaceans To Anthropogenic Noise'},
#   {'id': 75,
#    'author': 'J Sueur',
#    '#times_cited': 922.0,
#    'titles': 'Bioacoustics Approaches In Biodiversity Inventories<br>Assessing Biodiversity With Sound: Do Acoustic Diversity Indices Reflect Phylogenetic And Functional Diversities Of Bird Communities?<br>Ecoacoustics: The Ecological Investigation And Interpretation Of Environmental Sound<br>Acoustic Indices For Biodiversity Assessment And Landscape Investigation<br>Hay Meadow Vibroscape And Interactions Within Insect Vibrational Community'},
#   {'id': 76,
#    'author': 'Dr Ketten',
#    '#times_cited': 919.0,
#    'titles': 'Estimates Of Blast Injury And Acoustic Trauma Zones For Marine Mammals From Underwater Explosions<br>How Is Sound Conducted To The Cochlea In Toothed Whales?<br>Marine Mammal Sensory Systems<br>Marine Mammal Auditory Systems: A Summary Of Audiometric And Anatomical Data And Implications For Underwater Acoustic Impacts<br>A Model And Experimental Approach To The Middle Ear Transfer Function Related To Hearing In The Humpback Whale (Megaptera Novaeangliae)<br>Cetacean Ears'},
#   {'id': 77,
#    'author': 'A Gasc',
#    '#times_cited': 912.0,
#    'titles': 'Monitoring Animal Diversity Using Acoustic Indices: Implementation In A Temperate Woodland<br>Assessing Biodiversity With Sound: Do Acoustic Diversity Indices Reflect Phylogenetic And Functional Diversities Of Bird Communities?<br>Screening Large Audio Datasets To Determine The Time And Space Distribution Of Screaming Piha Birds In A Tropical Forest<br>First Description Of Underwater Acoustic Diversity In Three Temperate Ponds<br>Acoustic Indices For Biodiversity Assessment And Landscape Investigation'},
#   {'id': 78,
#    'author': 'I Van Opzeeland',
#    '#times_cited': 908.0,
#    'titles': 'A Noisy Spring: The Impact Of Globally Rising Underwater Sound Levels On Fish'},
#   {'id': 79,
#    'author': 'Se Parks',
#    '#times_cited': 903.0,
#    'titles': 'Individual Right Whales Call Louder In Increased Environmental Noise<br>Evidence That Ship Noise Increases Stress In Right Whales'},
#   {'id': 80,
#    'author': 'Dk Mellinger',
#    '#times_cited': 861.0,
#    'titles': 'Mobysound: A Reference Archive For Studying Automatic Recognition Of Marine Mammal Sounds<br>Cetacean Population Density Estimation From Single Fixed Sensors Using Passive Acoustics<br>Aas Endurance: An Autonomous Acoustic Sailboat For Marine Mammal Research<br>The Energy Ratio Mapping Algorithm: A Tool To Improve The Energy-Based Detection Of Odontocete Echolocation Clicks<br>An Overview Of Fixed Passive Acoustic Observation Methods For Cetaceans'},
#   {'id': 81,
#    'author': 'Ke Hunt',
#    '#times_cited': 856.0,
#    'titles': 'Overcoming The Challenges Of Studying Conservation Physiology In Large Whales: A Review Of Available Methods<br>Baleen Hormones: A Novel Tool For Retrospective Assessment Of Stress And Reproduction In Bowhead Whales (Balaena Mysticetus)<br>Evidence That Ship Noise Increases Stress In Right Whales'},
#   {'id': 82,
#    'author': 'A Berta',
#    '#times_cited': 855.0,
#    'titles': 'Marine Mammals: Evolutionary Biology'},
#   {'id': 83,
#    'author': 'Km Kovacs',
#    '#times_cited': 855.0,
#    'titles': 'Marine Mammals: Evolutionary Biology'},
#   {'id': 84,
#    'author': 'Jl Sumich',
#    '#times_cited': 855.0,
#    'titles': 'Marine Mammals: Evolutionary Biology'},
#   {'id': 85,
#    'author': 'T Haug',
#    '#times_cited': 852.0,
#    'titles': 'Do Harp Seals Phoca Groenlandica Exhibit Particular Prey Preferences?<br>Forskerutvalg Om Sjøpattedyr 2020-Tilrådning Om Forskning Og Forvaltning<br>Forskerutvalg Om Sjøpattedyr 2021<br>Food Webs And Carbon Flux In The Barents Sea<br>Prey Preference And Niche Overlap Of Ringed Seals Phoca Hispida And Harp Seals P. Groenlandica In The Barents Sea<br>Variations In Minke Whale (Balaenoptera Acutorostrata) Diet And Body Condition In Response To Ecosystem Changes In The Barents Sea<br>Lipids And Trophic Linkages In Harp Seal (Phoca Groenlandica) From The Eastern Barents Sea<br>A Review Of The Battle For Food In The Barents Sea: Cod Vs. Marine Mammals'},
#   {'id': 86,
#    'author': 'E Deblois',
#    '#times_cited': 847.0,
#    'titles': 'Recruitment In Marine Fishes: Is It Regulated By Starvation And Predation In The Egg And Larval Stages?'},
#   {'id': 87,
#    'author': 'C Erbe',
#    '#times_cited': 819.0,
#    'titles': 'Underwater Acoustics: Noise And The Effects On Marine Mammals<br>Communication Masking In Marine Mammals: A Review And Research Strategy<br>Underwater Sound And Vibration From Offshore Petroleum Activities And Their Potential Effects On Marine Fauna: An Australian Perspective<br>Effects Of Noise On Marine Mammals<br>Zones Of Impact Around Icebreakers Affecting Beluga Whales In The Beaufort Sea<br>Sounding The Call For A Global Library Of Underwater Biological Sounds<br>Sounding The Call For A Global Library Of Biological Underwater Sounds<br>Mapping Cumulative Noise From Shipping To Inform Marine Spatial Planning<br>Effects Of Underwater Noise On Marine Mammals'},
#   {'id': 88,
#    'author': 'Dp Nowacek',
#    '#times_cited': 818.0,
#    'titles': 'Soundscape Of An Indo-Pacific Humpback Dolphin (Sousa Chinensis) Hotspot Before Windfarm Construction In The Pearl River Estuary, China: Do Dolphin Engage In\xa0…<br>Responses Of Cetaceans To Anthropogenic Noise'},
#   {'id': 89,
#    'author': 'Lh Thorne',
#    '#times_cited': 805.0,
#    'titles': 'Responses Of Cetaceans To Anthropogenic Noise'},
#   {'id': 90,
#    'author': 'Ar Whiteley',
#    '#times_cited': 804.0,
#    'titles': 'Estimating Landscape Resistance To Movement: A Review'},
#   {'id': 91,
#    'author': 'K Mcgarigal',
#    '#times_cited': 804.0,
#    'titles': 'Estimating Landscape Resistance To Movement: A Review'},
#   {'id': 92,
#    'author': 'Ka Zeller',
#    '#times_cited': 804.0,
#    'titles': 'Estimating Landscape Resistance To Movement: A Review'},
#   {'id': 93,
#    'author': 'Wwl Au',
#    '#times_cited': 797.0,
#    'titles': 'Principles Of Marine Bioacoustics<br>Sonar Recognition Of Targets Embedded In Sediment<br>Seasonal And Diurnal Trends Of Chorusing Humpback Whales Wintering In Waters Off Western Maui'},
#   {'id': 94,
#    'author': 'Cj Brown',
#    '#times_cited': 792.0,
#    'titles': 'Benthic Habitat Mapping: A Review Of Progress Towards Improved Understanding Of The Spatial Ecology Of The Seafloor Using Acoustic Techniques<br>Developments In The Application Of Multibeam Sonar Backscatter For Seafloor Habitat Mapping'},
#   {'id': 95,
#    'author': 'Rm Rolland',
#    '#times_cited': 775.0,
#    'titles': 'Overcoming The Challenges Of Studying Conservation Physiology In Large Whales: A Review Of Available Methods<br>Evidence That Ship Noise Increases Stress In Right Whales'},
#   {'id': 96,
#    'author': 'F Ladich',
#    '#times_cited': 745.0,
#    'titles': 'Diversity In Fish Auditory Systems: One Of The Riddles Of Sensory Biology<br>Acoustic Communication In Terrestrial And Aquatic Vertebrates<br>Acoustic Communication In Fishes: Temperature Plays A Role<br>Ecology Of Sound Communication In Fishes<br>Diversity Of Inner Ears In Fishes: Possible Contribution Towards Hearing Improvements And Evolutionary Considerations<br>Sound Pressure And Particle Acceleration Audiograms In Three Marine Fish Species From The Adriatic Sea<br>Enigmatic Ear Stones: What We Know About The Functional Role And Evolution Of Fish Otoliths<br>Effects Of Ambient And Boat Noise On Hearing And Communication In Three Fish Species Living In A Marine Protected Area (Miramare, Italy)'},
#   {'id': 97,
#    'author': 'A Frantzis',
#    '#times_cited': 723.0,
#    'titles': "A Review Of The Effects Of Seismic Surveys On Marine Mammals<br>Mixed-Species Associations Of Striped Dolphins (Stenella Coeruleoalba), Short-Beaked Common Dolphins (Delphinus Delphis), And Risso'S Dolphins (Grampus\xa0…<br>Current Knowledge Of The Cetacean Fauna Of The Greek Seas"},
#   {'id': 98,
#    'author': 'B Møhl',
#    '#times_cited': 720.0,
#    'titles': 'Estimating Source Position Accuracy Of A Large-Aperture Hydrophone Array For Bioacoustics<br>The Monopulsed Nature Of Sperm Whale Clicks<br>Male Sperm Whale (Physeter Macrocephalus) Acoustics In A High-Latitude Habitat: Implications For Echolocation And Communication'},
#   {'id': 99,
#    'author': 'Se Moore',
#    '#times_cited': 714.0,
#    'titles': 'A New Framework For Assessing The Effects Of Anthropogenic Sound On Marine Mammals In A Rapidly Changing Arctic<br>An Overview Of Fixed Passive Acoustic Observation Methods For Cetaceans'}],
#  'coauthors_edges': [{'id_author1': 68, 'id_author2': 7, 'number': 12},
#   {'id_author1': 21, 'id_author2': 75, 'number': 5},
#   {'id_author1': 0, 'id_author2': 1, 'number': 5},
#   {'id_author1': 7, 'id_author2': 47, 'number': 4},
#   {'id_author1': 77, 'id_author2': 75, 'number': 4},
#   {'id_author1': 15, 'id_author2': 46, 'number': 4},
#   {'id_author1': 40, 'id_author2': 8, 'number': 3},
#   {'id_author1': 40, 'id_author2': 59, 'number': 3},
#   {'id_author1': 47, 'id_author2': 93, 'number': 3},
#   {'id_author1': 8, 'id_author2': 59, 'number': 3},
#   {'id_author1': 10, 'id_author2': 14, 'number': 3},
#   {'id_author1': 8, 'id_author2': 80, 'number': 3},
#   {'id_author1': 22, 'id_author2': 9, 'number': 3},
#   {'id_author1': 98, 'id_author2': 38, 'number': 3},
#   {'id_author1': 17, 'id_author2': 32, 'number': 3},
#   {'id_author1': 21, 'id_author2': 77, 'number': 2},
#   {'id_author1': 17, 'id_author2': 52, 'number': 2},
#   {'id_author1': 10, 'id_author2': 79, 'number': 2},
#   {'id_author1': 38, 'id_author2': 53, 'number': 2},
#   {'id_author1': 52, 'id_author2': 32, 'number': 2},
#   {'id_author1': 21, 'id_author2': 32, 'number': 2},
#   {'id_author1': 21, 'id_author2': 17, 'number': 2},
#   {'id_author1': 74, 'id_author2': 89, 'number': 2},
#   {'id_author1': 50, 'id_author2': 46, 'number': 2},
#   {'id_author1': 81, 'id_author2': 95, 'number': 2},
#   {'id_author1': 24, 'id_author2': 23, 'number': 2},
#   {'id_author1': 71, 'id_author2': 72, 'number': 2},
#   {'id_author1': 58, 'id_author2': 53, 'number': 2},
#   {'id_author1': 17, 'id_author2': 51, 'number': 2},
#   {'id_author1': 88, 'id_author2': 89, 'number': 2},
#   {'id_author1': 21, 'id_author2': 52, 'number': 2},
#   {'id_author1': 38, 'id_author2': 14, 'number': 2},
#   {'id_author1': 39, 'id_author2': 22, 'number': 2},
#   {'id_author1': 88, 'id_author2': 74, 'number': 2},
#   {'id_author1': 58, 'id_author2': 14, 'number': 2},
#   {'id_author1': 19, 'id_author2': 20, 'number': 1},
#   {'id_author1': 80, 'id_author2': 99, 'number': 1},
#   {'id_author1': 91, 'id_author2': 92, 'number': 1},
#   {'id_author1': 48, 'id_author2': 99, 'number': 1},
#   {'id_author1': 33, 'id_author2': 2, 'number': 1},
#   {'id_author1': 40, 'id_author2': 50, 'number': 1},
#   {'id_author1': 35, 'id_author2': 34, 'number': 1},
#   {'id_author1': 29, 'id_author2': 28, 'number': 1},
#   {'id_author1': 66, 'id_author2': 64, 'number': 1},
#   {'id_author1': 8, 'id_author2': 9, 'number': 1},
#   {'id_author1': 36, 'id_author2': 34, 'number': 1},
#   {'id_author1': 40, 'id_author2': 48, 'number': 1},
#   {'id_author1': 12, 'id_author2': 13, 'number': 1},
#   {'id_author1': 60, 'id_author2': 61, 'number': 1},
#   {'id_author1': 18, 'id_author2': 16, 'number': 1},
#   {'id_author1': 66, 'id_author2': 67, 'number': 1},
#   {'id_author1': 45, 'id_author2': 44, 'number': 1},
#   {'id_author1': 4, 'id_author2': 6, 'number': 1},
#   {'id_author1': 67, 'id_author2': 64, 'number': 1},
#   {'id_author1': 53, 'id_author2': 9, 'number': 1},
#   {'id_author1': 84, 'id_author2': 83, 'number': 1},
#   {'id_author1': 36, 'id_author2': 35, 'number': 1},
#   {'id_author1': 95, 'id_author2': 79, 'number': 1},
#   {'id_author1': 4, 'id_author2': 3, 'number': 1},
#   {'id_author1': 65, 'id_author2': 66, 'number': 1},
#   {'id_author1': 2, 'id_author2': 70, 'number': 1},
#   {'id_author1': 51, 'id_author2': 32, 'number': 1},
#   {'id_author1': 86, 'id_author2': 49, 'number': 1},
#   {'id_author1': 78, 'id_author2': 70, 'number': 1},
#   {'id_author1': 62, 'id_author2': 60, 'number': 1},
#   {'id_author1': 98, 'id_author2': 14, 'number': 1},
#   {'id_author1': 62, 'id_author2': 61, 'number': 1},
#   {'id_author1': 29, 'id_author2': 31, 'number': 1},
#   {'id_author1': 57, 'id_author2': 25, 'number': 1},
#   {'id_author1': 22, 'id_author2': 14, 'number': 1},
#   {'id_author1': 11, 'id_author2': 13, 'number': 1},
#   {'id_author1': 11, 'id_author2': 12, 'number': 1},
#   {'id_author1': 65, 'id_author2': 64, 'number': 1},
#   {'id_author1': 19, 'id_author2': 16, 'number': 1},
#   {'id_author1': 25, 'id_author2': 69, 'number': 1},
#   {'id_author1': 90, 'id_author2': 91, 'number': 1},
#   {'id_author1': 2, 'id_author2': 78, 'number': 1},
#   {'id_author1': 82, 'id_author2': 83, 'number': 1},
#   {'id_author1': 26, 'id_author2': 27, 'number': 1},
#   {'id_author1': 10, 'id_author2': 53, 'number': 1},
#   {'id_author1': 31, 'id_author2': 28, 'number': 1},
#   {'id_author1': 42, 'id_author2': 43, 'number': 1},
#   {'id_author1': 19, 'id_author2': 18, 'number': 1},
#   {'id_author1': 15, 'id_author2': 50, 'number': 1},
#   {'id_author1': 20, 'id_author2': 16, 'number': 1},
#   {'id_author1': 81, 'id_author2': 79, 'number': 1},
#   {'id_author1': 65, 'id_author2': 67, 'number': 1},
#   {'id_author1': 6, 'id_author2': 3, 'number': 1},
#   {'id_author1': 18, 'id_author2': 20, 'number': 1},
#   {'id_author1': 4, 'id_author2': 5, 'number': 1},
#   {'id_author1': 6, 'id_author2': 5, 'number': 1},
#   {'id_author1': 31, 'id_author2': 30, 'number': 1},
#   {'id_author1': 29, 'id_author2': 30, 'number': 1},
#   {'id_author1': 25, 'id_author2': 39, 'number': 1},
#   {'id_author1': 39, 'id_author2': 69, 'number': 1},
#   {'id_author1': 5, 'id_author2': 3, 'number': 1},
#   {'id_author1': 10, 'id_author2': 9, 'number': 1},
#   {'id_author1': 82, 'id_author2': 84, 'number': 1},
#   {'id_author1': 40, 'id_author2': 99, 'number': 1},
#   {'id_author1': 30, 'id_author2': 28, 'number': 1},
#   {'id_author1': 90, 'id_author2': 92, 'number': 1},
#   {'id_author1': 55, 'id_author2': 54, 'number': 1}],
#  'citing_edges': [{'id_author1': 82, 'id_author2': 4, 'number': 1},
#   {'id_author1': 82, 'id_author2': 6, 'number': 1},
#   {'id_author1': 82, 'id_author2': 5, 'number': 1},
#   {'id_author1': 82, 'id_author2': 3, 'number': 1},
#   {'id_author1': 21, 'id_author2': 56, 'number': 1},
#   {'id_author1': 77, 'id_author2': 56, 'number': 1},
#   {'id_author1': 77, 'id_author2': 75, 'number': 3},
#   {'id_author1': 11, 'id_author2': 8, 'number': 1},
#   {'id_author1': 68, 'id_author2': 68, 'number': 4},
#   {'id_author1': 68, 'id_author2': 7, 'number': 6},
#   {'id_author1': 68, 'id_author2': 40, 'number': 1},
#   {'id_author1': 68, 'id_author2': 87, 'number': 2},
#   {'id_author1': 68, 'id_author2': 8, 'number': 1},
#   {'id_author1': 68, 'id_author2': 56, 'number': 1},
#   {'id_author1': 68, 'id_author2': 47, 'number': 1},
#   {'id_author1': 68, 'id_author2': 59, 'number': 1},
#   {'id_author1': 68, 'id_author2': 93, 'number': 1},
#   {'id_author1': 58, 'id_author2': 40, 'number': 2},
#   {'id_author1': 58, 'id_author2': 87, 'number': 1},
#   {'id_author1': 58, 'id_author2': 76, 'number': 2},
#   {'id_author1': 58, 'id_author2': 10, 'number': 1},
#   {'id_author1': 58, 'id_author2': 14, 'number': 1},
#   {'id_author1': 58, 'id_author2': 48, 'number': 2},
#   {'id_author1': 58, 'id_author2': 99, 'number': 2},
#   {'id_author1': 7, 'id_author2': 68, 'number': 3},
#   {'id_author1': 7, 'id_author2': 7, 'number': 7},
#   {'id_author1': 7, 'id_author2': 40, 'number': 1},
#   {'id_author1': 7, 'id_author2': 87, 'number': 3},
#   {'id_author1': 7, 'id_author2': 8, 'number': 1},
#   {'id_author1': 7, 'id_author2': 47, 'number': 1},
#   {'id_author1': 7, 'id_author2': 59, 'number': 1},
#   {'id_author1': 7, 'id_author2': 93, 'number': 1},
#   {'id_author1': 98, 'id_author2': 98, 'number': 2},
#   {'id_author1': 98, 'id_author2': 38, 'number': 2},
#   {'id_author1': 17, 'id_author2': 75, 'number': 1},
#   {'id_author1': 40, 'id_author2': 40, 'number': 2},
#   {'id_author1': 40, 'id_author2': 8, 'number': 1},
#   {'id_author1': 40, 'id_author2': 76, 'number': 1},
#   {'id_author1': 40, 'id_author2': 9, 'number': 1},
#   {'id_author1': 40, 'id_author2': 48, 'number': 1},
#   {'id_author1': 40, 'id_author2': 99, 'number': 1},
#   {'id_author1': 40, 'id_author2': 59, 'number': 1},
#   {'id_author1': 87, 'id_author2': 7, 'number': 1},
#   {'id_author1': 87, 'id_author2': 40, 'number': 1},
#   {'id_author1': 87, 'id_author2': 87, 'number': 2},
#   {'id_author1': 87, 'id_author2': 8, 'number': 1},
#   {'id_author1': 87, 'id_author2': 59, 'number': 1},
#   {'id_author1': 57, 'id_author2': 40, 'number': 1},
#   {'id_author1': 57, 'id_author2': 8, 'number': 1},
#   {'id_author1': 57, 'id_author2': 59, 'number': 1},
#   {'id_author1': 94, 'id_author2': 41, 'number': 2},
#   {'id_author1': 8, 'id_author2': 40, 'number': 2},
#   {'id_author1': 8, 'id_author2': 87, 'number': 1},
#   {'id_author1': 8, 'id_author2': 8, 'number': 3},
#   {'id_author1': 8, 'id_author2': 80, 'number': 2},
#   {'id_author1': 8, 'id_author2': 76, 'number': 2},
#   {'id_author1': 8, 'id_author2': 9, 'number': 1},
#   {'id_author1': 8, 'id_author2': 48, 'number': 1},
#   {'id_author1': 8, 'id_author2': 99, 'number': 1},
#   {'id_author1': 8, 'id_author2': 59, 'number': 1},
#   {'id_author1': 36, 'id_author2': 4, 'number': 1},
#   {'id_author1': 36, 'id_author2': 6, 'number': 1},
#   {'id_author1': 36, 'id_author2': 5, 'number': 1},
#   {'id_author1': 36, 'id_author2': 3, 'number': 1},
#   {'id_author1': 80, 'id_author2': 8, 'number': 2},
#   {'id_author1': 80, 'id_author2': 80, 'number': 2},
#   {'id_author1': 80, 'id_author2': 47, 'number': 1},
#   {'id_author1': 80, 'id_author2': 22, 'number': 1},
#   {'id_author1': 80, 'id_author2': 9, 'number': 1},
#   {'id_author1': 80, 'id_author2': 93, 'number': 1},
#   {'id_author1': 24, 'id_author2': 98, 'number': 1},
#   {'id_author1': 24, 'id_author2': 4, 'number': 1},
#   {'id_author1': 24, 'id_author2': 6, 'number': 1},
#   {'id_author1': 24, 'id_author2': 5, 'number': 1},
#   {'id_author1': 24, 'id_author2': 38, 'number': 1},
#   {'id_author1': 24, 'id_author2': 3, 'number': 1},
#   {'id_author1': 88, 'id_author2': 76, 'number': 1},
#   {'id_author1': 88, 'id_author2': 22, 'number': 1},
#   {'id_author1': 88, 'id_author2': 9, 'number': 1},
#   {'id_author1': 76, 'id_author2': 76, 'number': 2},
#   {'id_author1': 74, 'id_author2': 76, 'number': 1},
#   {'id_author1': 74, 'id_author2': 22, 'number': 1},
#   {'id_author1': 74, 'id_author2': 9, 'number': 1},
#   {'id_author1': 96, 'id_author2': 96, 'number': 5},
#   {'id_author1': 96, 'id_author2': 9, 'number': 1},
#   {'id_author1': 12, 'id_author2': 8, 'number': 1},
#   {'id_author1': 19, 'id_author2': 76, 'number': 1},
#   {'id_author1': 56, 'id_author2': 56, 'number': 4},
#   {'id_author1': 33, 'id_author2': 4, 'number': 1},
#   {'id_author1': 33, 'id_author2': 6, 'number': 1},
#   {'id_author1': 33, 'id_author2': 5, 'number': 1},
#   {'id_author1': 33, 'id_author2': 9, 'number': 2},
#   {'id_author1': 33, 'id_author2': 3, 'number': 1},
#   {'id_author1': 2, 'id_author2': 4, 'number': 2},
#   {'id_author1': 2, 'id_author2': 6, 'number': 2},
#   {'id_author1': 2, 'id_author2': 5, 'number': 2},
#   {'id_author1': 2, 'id_author2': 96, 'number': 2},
#   {'id_author1': 2, 'id_author2': 3, 'number': 2},
#   {'id_author1': 37, 'id_author2': 22, 'number': 1},
#   {'id_author1': 37, 'id_author2': 9, 'number': 1},
#   {'id_author1': 78, 'id_author2': 4, 'number': 1},
#   {'id_author1': 78, 'id_author2': 6, 'number': 1},
#   {'id_author1': 78, 'id_author2': 5, 'number': 1},
#   {'id_author1': 78, 'id_author2': 3, 'number': 1},
#   {'id_author1': 63, 'id_author2': 4, 'number': 1},
#   {'id_author1': 63, 'id_author2': 6, 'number': 1},
#   {'id_author1': 63, 'id_author2': 5, 'number': 1},
#   {'id_author1': 63, 'id_author2': 3, 'number': 1},
#   {'id_author1': 26, 'id_author2': 41, 'number': 1},
#   {'id_author1': 23, 'id_author2': 98, 'number': 1},
#   {'id_author1': 23, 'id_author2': 4, 'number': 1},
#   {'id_author1': 23, 'id_author2': 6, 'number': 1},
#   {'id_author1': 23, 'id_author2': 5, 'number': 1},
#   {'id_author1': 23, 'id_author2': 38, 'number': 1},
#   {'id_author1': 23, 'id_author2': 3, 'number': 1},
#   {'id_author1': 75, 'id_author2': 56, 'number': 1},
#   {'id_author1': 75, 'id_author2': 75, 'number': 1},
#   {'id_author1': 15, 'id_author2': 4, 'number': 1},
#   {'id_author1': 15, 'id_author2': 6, 'number': 1},
#   {'id_author1': 15, 'id_author2': 5, 'number': 1},
#   {'id_author1': 15, 'id_author2': 76, 'number': 2},
#   {'id_author1': 15, 'id_author2': 15, 'number': 2},
#   {'id_author1': 15, 'id_author2': 46, 'number': 2},
#   {'id_author1': 15, 'id_author2': 3, 'number': 1},
#   {'id_author1': 84, 'id_author2': 4, 'number': 1},
#   {'id_author1': 84, 'id_author2': 6, 'number': 1},
#   {'id_author1': 84, 'id_author2': 5, 'number': 1},
#   {'id_author1': 84, 'id_author2': 3, 'number': 1},
#   {'id_author1': 25, 'id_author2': 40, 'number': 1},
#   {'id_author1': 25, 'id_author2': 8, 'number': 1},
#   {'id_author1': 25, 'id_author2': 59, 'number': 1},
#   {'id_author1': 71, 'id_author2': 4, 'number': 1},
#   {'id_author1': 71, 'id_author2': 6, 'number': 1},
#   {'id_author1': 71, 'id_author2': 5, 'number': 1},
#   {'id_author1': 71, 'id_author2': 76, 'number': 1},
#   {'id_author1': 71, 'id_author2': 3, 'number': 1},
#   {'id_author1': 0, 'id_author2': 4, 'number': 1},
#   {'id_author1': 0, 'id_author2': 6, 'number': 1},
#   {'id_author1': 0, 'id_author2': 5, 'number': 1},
#   {'id_author1': 0, 'id_author2': 3, 'number': 1},
#   {'id_author1': 81, 'id_author2': 40, 'number': 1},
#   {'id_author1': 81, 'id_author2': 9, 'number': 1},
#   {'id_author1': 81, 'id_author2': 48, 'number': 1},
#   {'id_author1': 81, 'id_author2': 99, 'number': 1},
#   {'id_author1': 39, 'id_author2': 98, 'number': 1},
#   {'id_author1': 39, 'id_author2': 38, 'number': 1},
#   {'id_author1': 39, 'id_author2': 47, 'number': 1},
#   {'id_author1': 39, 'id_author2': 93, 'number': 1},
#   {'id_author1': 83, 'id_author2': 4, 'number': 1},
#   {'id_author1': 83, 'id_author2': 6, 'number': 1},
#   {'id_author1': 83, 'id_author2': 5, 'number': 1},
#   {'id_author1': 83, 'id_author2': 3, 'number': 1},
#   {'id_author1': 89, 'id_author2': 76, 'number': 1},
#   {'id_author1': 89, 'id_author2': 22, 'number': 1},
#   {'id_author1': 89, 'id_author2': 9, 'number': 1},
#   {'id_author1': 10, 'id_author2': 7, 'number': 1},
#   {'id_author1': 10, 'id_author2': 98, 'number': 1},
#   {'id_author1': 10, 'id_author2': 10, 'number': 4},
#   {'id_author1': 10, 'id_author2': 38, 'number': 1},
#   {'id_author1': 10, 'id_author2': 22, 'number': 2},
#   {'id_author1': 10, 'id_author2': 9, 'number': 3},
#   {'id_author1': 10, 'id_author2': 14, 'number': 4},
#   {'id_author1': 38, 'id_author2': 98, 'number': 4},
#   {'id_author1': 38, 'id_author2': 10, 'number': 1},
#   {'id_author1': 38, 'id_author2': 38, 'number': 4},
#   {'id_author1': 38, 'id_author2': 9, 'number': 1},
#   {'id_author1': 38, 'id_author2': 14, 'number': 1},
#   {'id_author1': 47, 'id_author2': 7, 'number': 1},
#   {'id_author1': 47, 'id_author2': 15, 'number': 1},
#   {'id_author1': 47, 'id_author2': 22, 'number': 1},
#   {'id_author1': 47, 'id_author2': 9, 'number': 1},
#   {'id_author1': 47, 'id_author2': 46, 'number': 1},
#   {'id_author1': 50, 'id_author2': 40, 'number': 2},
#   {'id_author1': 50, 'id_author2': 8, 'number': 1},
#   {'id_author1': 50, 'id_author2': 15, 'number': 2},
#   {'id_author1': 50, 'id_author2': 9, 'number': 1},
#   {'id_author1': 50, 'id_author2': 48, 'number': 1},
#   {'id_author1': 50, 'id_author2': 99, 'number': 1},
#   {'id_author1': 50, 'id_author2': 46, 'number': 2},
#   {'id_author1': 50, 'id_author2': 59, 'number': 1},
#   {'id_author1': 22, 'id_author2': 4, 'number': 1},
#   {'id_author1': 22, 'id_author2': 6, 'number': 1},
#   {'id_author1': 22, 'id_author2': 5, 'number': 1},
#   {'id_author1': 22, 'id_author2': 47, 'number': 1},
#   {'id_author1': 22, 'id_author2': 3, 'number': 1},
#   {'id_author1': 22, 'id_author2': 93, 'number': 1},
#   {'id_author1': 22, 'id_author2': 41, 'number': 1},
#   {'id_author1': 18, 'id_author2': 76, 'number': 1},
#   {'id_author1': 35, 'id_author2': 4, 'number': 1},
#   {'id_author1': 35, 'id_author2': 6, 'number': 1},
#   {'id_author1': 35, 'id_author2': 5, 'number': 1},
#   {'id_author1': 35, 'id_author2': 3, 'number': 1},
#   {'id_author1': 70, 'id_author2': 4, 'number': 1},
#   {'id_author1': 70, 'id_author2': 6, 'number': 1},
#   {'id_author1': 70, 'id_author2': 5, 'number': 1},
#   {'id_author1': 70, 'id_author2': 3, 'number': 1},
#   {'id_author1': 53, 'id_author2': 22, 'number': 1},
#   {'id_author1': 53, 'id_author2': 9, 'number': 2},
#   {'id_author1': 9, 'id_author2': 4, 'number': 1},
#   {'id_author1': 9, 'id_author2': 6, 'number': 1},
#   {'id_author1': 9, 'id_author2': 5, 'number': 1},
#   {'id_author1': 9, 'id_author2': 22, 'number': 1},
#   {'id_author1': 9, 'id_author2': 9, 'number': 1},
#   {'id_author1': 9, 'id_author2': 3, 'number': 1},
#   {'id_author1': 14, 'id_author2': 98, 'number': 4},
#   {'id_author1': 14, 'id_author2': 10, 'number': 2},
#   {'id_author1': 14, 'id_author2': 38, 'number': 4},
#   {'id_author1': 14, 'id_author2': 22, 'number': 1},
#   {'id_author1': 14, 'id_author2': 9, 'number': 1},
#   {'id_author1': 14, 'id_author2': 14, 'number': 2},
#   {'id_author1': 14, 'id_author2': 41, 'number': 1},
#   {'id_author1': 34, 'id_author2': 4, 'number': 1},
#   {'id_author1': 34, 'id_author2': 6, 'number': 1},
#   {'id_author1': 34, 'id_author2': 5, 'number': 1},
#   {'id_author1': 34, 'id_author2': 3, 'number': 1},
#   {'id_author1': 95, 'id_author2': 9, 'number': 1},
#   {'id_author1': 48, 'id_author2': 40, 'number': 3},
#   {'id_author1': 48, 'id_author2': 8, 'number': 1},
#   {'id_author1': 48, 'id_author2': 48, 'number': 2},
#   {'id_author1': 48, 'id_author2': 99, 'number': 2},
#   {'id_author1': 48, 'id_author2': 59, 'number': 1},
#   {'id_author1': 99, 'id_author2': 22, 'number': 1},
#   {'id_author1': 99, 'id_author2': 9, 'number': 1},
#   {'id_author1': 79, 'id_author2': 10, 'number': 1},
#   {'id_author1': 79, 'id_author2': 9, 'number': 2},
#   {'id_author1': 79, 'id_author2': 14, 'number': 1},
#   {'id_author1': 52, 'id_author2': 8, 'number': 2},
#   {'id_author1': 52, 'id_author2': 80, 'number': 2},
#   {'id_author1': 52, 'id_author2': 56, 'number': 1},
#   {'id_author1': 1, 'id_author2': 4, 'number': 1},
#   {'id_author1': 1, 'id_author2': 6, 'number': 1},
#   {'id_author1': 1, 'id_author2': 5, 'number': 1},
#   {'id_author1': 1, 'id_author2': 3, 'number': 1},
#   {'id_author1': 46, 'id_author2': 76, 'number': 1},
#   {'id_author1': 46, 'id_author2': 15, 'number': 2},
#   {'id_author1': 46, 'id_author2': 46, 'number': 2},
#   {'id_author1': 85, 'id_author2': 85, 'number': 5},
#   {'id_author1': 13, 'id_author2': 8, 'number': 1},
#   {'id_author1': 20, 'id_author2': 76, 'number': 1},
#   {'id_author1': 72, 'id_author2': 4, 'number': 1},
#   {'id_author1': 72, 'id_author2': 6, 'number': 1},
#   {'id_author1': 72, 'id_author2': 5, 'number': 1},
#   {'id_author1': 72, 'id_author2': 76, 'number': 1},
#   {'id_author1': 72, 'id_author2': 3, 'number': 1},
#   {'id_author1': 27, 'id_author2': 41, 'number': 1},
#   {'id_author1': 3, 'id_author2': 76, 'number': 1},
#   {'id_author1': 16, 'id_author2': 76, 'number': 1},
#   {'id_author1': 59, 'id_author2': 76, 'number': 2},
#   {'id_author1': 59, 'id_author2': 9, 'number': 1},
#   {'id_author1': 93, 'id_author2': 15, 'number': 1},
#   {'id_author1': 93, 'id_author2': 22, 'number': 1},
#   {'id_author1': 93, 'id_author2': 9, 'number': 1},
#   {'id_author1': 93, 'id_author2': 46, 'number': 1}]}

# %%
from pyvis.network import Network

def init_network(nodes, coauthors_edges, citing_edges):
    g = Network(notebook=True, 
            height='1000px', 
            width='1500px', 
            directed=True,
            bgcolor='#212121', 
            font_color='white')
    
    g.add_nodes(nodes.authors, 
                value=nodes["#times_cited"],
                label=nodes.authors, 
                title=nodes.titles
    )
    
    g.add_edges(list(coauthors_edges.itertuples(index=False, name=None)))
    
    edges_to_add = list(citing_edges.itertuples(index=False, name=None))
    for edge in edges_to_add:
        g.add_edge(edge[0], edge[1], value=edge[2], color="#4d4d00")
    
    return g


g = init_network(nodes, coauthors_edges, citing_edges)

options = """
var options = {
    "nodes": {
        "color": "#ffc900",
        "scaling": {
          "min": 5,
          "max": 50
        }
     },
     "edges": {
         "color": "#ec7e2f", 
         "opacity": "0.1"
     }
}
"""
g.set_options(options)

g.show("test.html")
# Out:
#         <iframe
#             width="1500px"
#             height="1000px"
#             src="test.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from pyvis.network import Network

NUMBER_OF_NODES = 300

g = Network(notebook=True, 
            height='1000px', 
            width='1500px', 
            directed=True,
            bgcolor='#212121', 
            font_color='white')

# nodes
authors_to_keep = total_num_citation_per_author.index.tolist()[:NUMBER_OF_NODES]

# value of nodes (influence on community)
authors_weight = total_num_citation_per_author.values.tolist()[:NUMBER_OF_NODES]

# titles
titles_to_keep = titles.loc[authors_to_keep].to_list()

# edges
froms = test.a1.to_list()
tos = test.a2.to_list()
weights = test.authors.to_list()

g.add_nodes(authors_to_keep, 
            value=authors_weight,
            label=authors_to_keep, 
            title=titles_to_keep
)

for edge in edges.items():
    g.add_edge(authors[0], authors[1], value=val, color="green")

for authors, val in pairs_to_keep.items():
    g.add_edge(authors[0], authors[1], value=val, color="green")

options = """
var options = {
    "nodes": {
        "color": "#ffc900",
        "scaling": {
          "min": 5,
          "max": 70
        }
     },
     "edges": {
         "color": "#ec7e2f", 
         "opacity": "0.1"
     }
}
"""
g.set_options(options)
g.show("ex.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 32>()
#      26 g.add_nodes(authors_to_keep,
#      27             value=authors_weight,
#      28             label=authors_to_keep,
#      29             title=titles_to_keep
#      30 )
#      32 for edge in edges.items():
# ---> 33     g.add_edge(authors[0], authors[1], value=val, color="green")
#      35 for authors, val in pairs_to_keep.items():
#      36     g.add_edge(authors[0], authors[1], value=val, color="green")
#
# NameError: name 'authors' is not defined

# %%
from pyvis.network import Network

NUMBER_OF_NODES = 100

g = Network(notebook=True, 
            height='1000px', 
            width='1500px', 
            directed=True,
            bgcolor='#212121', 
            font_color='white')

# nodes
authors_to_keep = total_num_citation_per_author.index.tolist()[:NUMBER_OF_NODES]

# value of nodes (influence on community)
authors_weight = total_num_citation_per_author.values.tolist()[:NUMBER_OF_NODES]

# titles
titles_to_keep = titles.loc[authors_to_keep].to_list()

# edges
edges_to_keep = edges.loc[ edges.author.isin(total_num_citation_per_author[:NUMBER_OF_NODES].index), :]
edges_to_keep = edges_to_keep.loc[ edges.cited_author.isin(total_num_citation_per_author[:NUMBER_OF_NODES].index), :]

froms = edges_to_keep.author.to_list()
tos = edges_to_keep.cited_author.to_list()
weights = map(int, edges_to_keep["# times citing"])

g.add_nodes(authors_to_keep, 
            value=authors_weight,
            label=authors_to_keep, 
            title=titles_to_keep
)

g.add_edges(zip(froms, tos, weights))

options = """
var options = {
    "nodes": {
        "color": "#ffc900",
        "scaling": {
          "min": 5,
          "max": 70
        }
     },
     "edges": {
         "color": "#ec7e2f", 
         "opacity": "0.1"
     }
}
"""
g.set_options(options)
g.show("ex.html")
# Out:
#         <iframe
#             width="1500px"
#             height="1000px"
#             src="ex.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
prolific_authors = (df.loc[:, ["title", "authors"]]
                      .drop_duplicates(subset="title")
                      .explode("authors")
                      .groupby("authors")
                      .count()
                      .sort_values("title", ascending=False)
                   )

prolific_authors[:10]

# %%
from pyvis.network import Network

NUMBER_OF_NODES = 100

g = Network(notebook=True, 
            height='1000px', 
            width='1500px', 
            directed=True,
            bgcolor='#212121', 
            font_color='white')

# nodes
authors_to_keep = total_num_citation_per_author.index.tolist()[:NUMBER_OF_NODES]

# value of nodes (influence on community)
authors_weight = total_num_citation_per_author.values.tolist()[:NUMBER_OF_NODES]

# titles
titles_to_keep = titles.loc[authors_to_keep].to_list()

# edges
edges_to_keep = edges.loc[ edges.author.isin(total_num_citation_per_author[:NUMBER_OF_NODES].index), :]
edges_to_keep = edges_to_keep.loc[ edges.cited_author.isin(total_num_citation_per_author[:NUMBER_OF_NODES].index), :]

froms = edges_to_keep.author.to_list()
tos = edges_to_keep.cited_author.to_list()
weights = map(int, edges_to_keep["# times citing"])

g.add_nodes(authors_to_keep, 
            value=authors_weight,
            label=authors_to_keep, 
            title=titles_to_keep
)

g.add_edges(zip(froms, tos, weights))

for authors, val in pairs_to_keep.items():
    g.add_edge(authors[0], authors[1], value=val, color="green", arrowStrikethrough=False)
    
options = """
var options = {
    "nodes": {
        "color": "#ffc900",
        "scaling": {
          "min": 5,
          "max": 70
        }
     },
     "edges": {
         "color": "#ec7e2f", 
         "opacity": "0.1"
     }
}
"""
g.set_options(options)
g.show("ex.html")
# Out:
#         <iframe
#             width="1500px"
#             height="1000px"
#             src="ex.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Communities

# %%
import community as community_louvain
import matplotlib.cm as cm
G = nx.from_pandas_edgelist(coauthors_edges, source="id_author1", target="id_author2")
partition = community_louvain.best_partition(G, weight='number')
nodes['group'] = nodes['id'].map(partition)
nodes.fillna(-1, inplace=True)

# %%
nodes
# Out:
#     id         author  #times_cited  \
# 0    0    Jw Bradbury        4395.0
# 1    1  Sl Vehrencamp        4395.0
# 2    2  H Slabbekoorn        3107.0
# 3    3  Wj Richardson        3080.0
# 4    4       Ci Malme        2842.0
# ..  ..            ...           ...
# 95  95     Rm Rolland         775.0
# 96  96       F Ladich         745.0
# 97  97     A Frantzis         723.0
# 98  98         B Møhl         720.0
# 99  99       Se Moore         714.0
#
#                                                titles  group
# 0                  Principles Of Animal Communication    3.0
# 1                  Principles Of Animal Communication    3.0
# 2   Population‐Level Consequences Of Seismic Surve...   17.0
# 3   Marine Mammals And Noise<br>Influences Of Man‐...    4.0
# 4                            Marine Mammals And Noise    4.0
# ..                                                ...    ...
# 95  Overcoming The Challenges Of Studying Conserva...    8.0
# 96  Diversity In Fish Auditory Systems: One Of The...   -1.0
# 97  A Review Of The Effects Of Seismic Surveys On ...   -1.0
# 98  Estimating Source Position Accuracy Of A Large...    8.0
# 99  A New Framework For Assessing The Effects Of A...    6.0
#
# [100 rows x 5 columns]
